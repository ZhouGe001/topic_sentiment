# %%
import word_cloud

# %%
# 读取txt文件中的文本数据
filename = '../数据文件/切词数据/切词-论文数据.txt'  # 替换为你的txt文件路径
# 词频分析
word_counts_dict = word_cloud.word_frequency(filename)
# 生成词云
word_cloud.generate_wordcloud(word_counts_dict)
